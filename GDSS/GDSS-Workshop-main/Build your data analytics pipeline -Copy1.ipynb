# %%
### Step 1: Import necessary Libraries
import pandas as pd #Data transformation
import requests  #establishing connection with the web/api

# %%
url='https://api.coincap.io/v2/assets'

# %%
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#json files are called semi-structured data
responsedata=response.json()
responsedata
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19727337.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1254232347778.7421082733328108',
#    'volumeUsd24Hr': '10442635998.9666159828229595',
#    'priceUsd': '63578.3911319983081484',
#    'changePercent24Hr': '-1.8876116270482910',
#    'vwap24Hr': '64513.8858409383567868',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120222728.1783115700000000',
#    'maxSupply': None,
#    'marketCapUsd': '407678008060.3933285585608744',
#    'volumeUsd24Hr': '6614263909.0353558051394749',
#    'priceUsd': '3391.0227644787326363',
#    'changePercent24Hr': '-1.4196188848735361',
#    'vwap24Hr': '3426.5667113271284740',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '113632416636.0384400000000000',
#    'maxSupply': None,
#    'marketCapUsd': '113697208007.8713115451836848',
#    'volumeUsd24Hr': '15989657217.2242741569992479',
#    'priceUsd': '1.0005701838766696',
#    'changePercent24Hr': '-0.0149997044124572',
#    'vwap24Hr': '1.0004569030754881',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '94290334283.1678562086414060',
#    'volumeUsd24Hr': '201077694.5008487198199126',
#    'priceUsd': '565.2858833032003845',
#    'changePercent24Hr': '-1.2803023727671828',
#    'vwap24Hr': '572.0088495368418330',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '464274532.9981066000000000',
#    'maxSupply': None,
#    'marketCapUsd': '72629019120.8561741118872127',
#    'volumeUsd24Hr': '748573293.4670278843723863',
#    'priceUsd': '156.4355008917802715',
#    'changePercent24Hr': '-1.0648013943480714',
#    'vwap24Hr': '158.1740592196204314',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '33769863394.4254150000000000',
#    'maxSupply': None,
#    'marketCapUsd': '33789085610.0668912533355886',
#    'volumeUsd24Hr': '1653537618.0277667318133863',
#    'priceUsd': '1.0005692121231574',
#    'changePercent24Hr': '0.0111292340651347',
#    'vwap24Hr': '1.0002737039390059',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'xrp',
#    'rank': '7',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '25588888761.5443640665530880',
#    'volumeUsd24Hr': '1331893060.8164127150807072',
#    'priceUsd': '0.5635819007258992',
#    'changePercent24Hr': '-6.4762237976156136',
#    'vwap24Hr': '0.6009842165056731',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'dogecoin',
#    'rank': '8',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '145167606383.7052600000000000',
#    'maxSupply': None,
#    'marketCapUsd': '17145066390.5305507563749952',
#    'volumeUsd24Hr': '346948193.8328063728362488',
#    'priceUsd': '0.1181053185186020',
#    'changePercent24Hr': '-4.1125334640166095',
#    'vwap24Hr': '0.1219492735273440',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'cardano',
#    'rank': '9',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35889941128.2900000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '15285000627.0822513015100508',
#    'volumeUsd24Hr': '157881331.9397858618136404',
#    'priceUsd': '0.4258853636021697',
#    'changePercent24Hr': '-4.7834015772954227',
#    'vwap24Hr': '0.4397337438661285',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'tron',
#    'rank': '10',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87100220287.2389000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '11649632243.0493797816743666',
#    'volumeUsd24Hr': '110774919.5705568928527624',
#    'priceUsd': '0.1337497448873407',
#    'changePercent24Hr': '-0.6046879568800435',
#    'vwap24Hr': '0.1341269172561167',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'avalanche',
#    'rank': '11',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '394712643.2037411000000000',
#    'maxSupply': '715748719.0000000000000000',
#    'marketCapUsd': '10606491613.7604559739386787',
#    'volumeUsd24Hr': '112586505.9550258119483902',
#    'priceUsd': '26.8714260776431275',
#    'changePercent24Hr': '-4.1235816167322467',
#    'vwap24Hr': '27.6148633192885409',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'shiba-inu',
#    'rank': '12',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589270698811007.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '10074538311.1622431609403995',
#    'volumeUsd24Hr': '540045469.0838199976066716',
#    'priceUsd': '0.0000170966218607',
#    'changePercent24Hr': '-9.8071156764484353',
#    'vwap24Hr': '0.0000177488818165',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '13',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '154782.1938814600000000',
#    'maxSupply': None,
#    'marketCapUsd': '9851484221.6172327428479685',
#    'volumeUsd24Hr': '31135128.9779294779990977',
#    'priceUsd': '63647.4000954011257274',
#    'changePercent24Hr': '-1.8084015492303537',
#    'vwap24Hr': '64532.1402792912820691',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'polkadot',
#    'rank': '14',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1389166152.9106700000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8455932097.4364979036181303',
#    'volumeUsd24Hr': '106090843.4534325197261606',
#    'priceUsd': '6.0870559505924376',
#    'changePercent24Hr': '-4.6141063636502590',
#    'vwap24Hr': '6.2838982114214608',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'chainlink',
#    'rank': '15',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '608099970.4527867000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8232561433.3643031422822883',
#    'volumeUsd24Hr': '146279789.3034101170838407',
#    'priceUsd': '13.5381710793940663',
#    'changePercent24Hr': '-4.3770725316046123',
#    'vwap24Hr': '13.8472822878623391',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'bitcoin-cash',
#    'rank': '16',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19734531.2500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '7382453412.5140108156446250',
#    'volumeUsd24Hr': '75554837.6288693693037943',
#    'priceUsd': '374.0881057164208456',
#    'changePercent24Hr': '-0.4749724712456424',
#    'vwap24Hr': '378.5927533116453861',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'near-protocol',
#    'rank': '17',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1103086274.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '6558317216.3533108082928074',
#    'volumeUsd24Hr': '94590031.6334998848686038',
#    'priceUsd': '5.9454254584925701',
#    'changePercent24Hr': '-2.2213677550133628',
#    'vwap24Hr': '6.1179316056000970',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'unus-sed-leo',
#    'rank': '18',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '925962453.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5399474065.2195481651033759',
#    'volumeUsd24Hr': '962847.0380900580752617',
#    'priceUsd': '5.8312019482840374',
#    'changePercent24Hr': '-0.9180745283474962',
#    'vwap24Hr': '5.7525934934936643',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'multi-collateral-dai',
#    'rank': '19',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5344554616.3276483611806898',
#    'volumeUsd24Hr': '106977843.2864082637279217',
#    'priceUsd': '0.9993765802411421',
#    'changePercent24Hr': '0.0306430095432278',
#    'vwap24Hr': '0.9998758430106118',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'litecoin',
#    'rank': '20',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74763787.3575049000000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '5335893960.3511910642017877',
#    'volumeUsd24Hr': '154649211.5427127685073819',
#    'priceUsd': '71.3700328587696421',
#    'changePercent24Hr': '-1.0843722767075625',
#    'vwap24Hr': '72.0823837300374176',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'polygon',
#    'rank': '21',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9897682387.4420720000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5105938126.7382096234188287',
#    'volumeUsd24Hr': '112797064.1711996784389889',
#    'priceUsd': '0.5158720927655240',
#    'changePercent24Hr': '-6.7432926705128459',
#    'vwap24Hr': '0.5403263243997129',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'uniswap',
#    'rank': '22',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '600034294.7100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4613444395.1986595098239855',
#    'volumeUsd24Hr': '87616111.5287679737705907',
#    'priceUsd': '7.6886345261788137',
#    'changePercent24Hr': '-4.9215590782920264',
#    'vwap24Hr': '7.9735215617635411',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'internet-computer',
#    'rank': '23',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '466717951.1227252500000000',
#    'maxSupply': None,
#    'marketCapUsd': '4499910981.6516594335017753',
#    'volumeUsd24Hr': '56901250.5702373392545500',
#    'priceUsd': '9.6416068223362397',
#    'changePercent24Hr': '-4.0950765529851558',
#    'vwap24Hr': '10.1161364954152864',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'fetch',
#    'rank': '24',
#    'symbol': 'FET',
#    'name': 'Artificial Superintelligence Alliance',
#    'supply': '2520000000.0000000000000000',
#    'maxSupply': '2630547141.0000000000000000',
#    'marketCapUsd': '3489369032.7780215400000000',
#    'volumeUsd24Hr': '73045646.9509954043176811',
#    'priceUsd': '1.3846702511023895',
#    'changePercent24Hr': '-6.3115588286254825',
#    'vwap24Hr': '1.4616840106366887',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'ethereum-classic',
#    'rank': '25',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '147968376.5242138000000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '3363569427.6754312860425018',
#    'volumeUsd24Hr': '60384540.0133401887280873',
#    'priceUsd': '22.7316775833180206',
#    'changePercent24Hr': '-2.7584412281488144',
#    'vwap24Hr': '23.1695609861201464',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'stellar',
#    'rank': '26',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '29309405074.1114900000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '2980655668.8138942097335677',
#    'volumeUsd24Hr': '65407702.7241827021049106',
#    'priceUsd': '0.1016962187146766',
#    'changePercent24Hr': '-6.8862421910588443',
#    'vwap24Hr': '0.1068251906973400',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'monero',
#    'rank': '27',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18446744.0737095500000000',
#    'maxSupply': None,
#    'marketCapUsd': '2949719936.9797495861794992',
#    'volumeUsd24Hr': '50289356.1455091418851318',
#    'priceUsd': '159.9046381948625005',
#    'changePercent24Hr': '0.1431619188549498',
#    'vwap24Hr': '160.5453457946095747',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'stacks',
#    'rank': '28',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1474818445.1475430000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '2668046274.5872227526599666',
#    'volumeUsd24Hr': '12276652.4146378106834546',
#    'priceUsd': '1.8090676065014277',
#    'changePercent24Hr': '-4.9422160439810388',
#    'vwap24Hr': '1.8896478247546370',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'maker',
#    'rank': '29',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '930401.8833898900000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '2574474629.7381997086564945',
#    'volumeUsd24Hr': '46899138.2375598474661624',
#    'priceUsd': '2767.0565544839423209',
#    'changePercent24Hr': '-3.2162325460574427',
#    'vwap24Hr': '2872.8793494836834351',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'filecoin',
#    'rank': '30',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '571671385.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2508575769.2840592787014465',
#    'volumeUsd24Hr': '93009455.3888836112035323',
#    'priceUsd': '4.3881429700807209',
#    'changePercent24Hr': '-6.7690885671563352',
#    'vwap24Hr': '4.5648180786696839',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'vechain',
#    'rank': '31',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '80985041177.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '2444232598.7979993686148133',
#    'volumeUsd24Hr': '18230769.0393698648950639',
#    'priceUsd': '0.0301812848802029',
#    'changePercent24Hr': '-4.2950239425201781',
#    'vwap24Hr': '0.0312402848557743',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'render-token',
#    'rank': '32',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '2334493578.1262714371497505',
#    'volumeUsd24Hr': '6660577.1325311220329602',
#    'priceUsd': '6.3160311214154873',
#    'changePercent24Hr': '-7.2441422680642540',
#    'vwap24Hr': '6.7063739325302564',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'crypto-com-coin',
#    'rank': '33',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '2318895232.1923303187596968',
#    'volumeUsd24Hr': '3067722.0203450327658156',
#    'priceUsd': '0.0917901268812854',
#    'changePercent24Hr': '-1.7683281064853759',
#    'vwap24Hr': '0.0932845797481223',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'arweave',
#    'rank': '34',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65652466.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '1958042584.2412702478887500',
#    'volumeUsd24Hr': '29966506.0462604735672985',
#    'priceUsd': '29.8243570049793750',
#    'changePercent24Hr': '-4.5910566144393127',
#    'vwap24Hr': '30.8254797909704865',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'the-graph',
#    'rank': '35',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9548531509.1654740000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1924968363.7773857169537749',
#    'volumeUsd24Hr': '24466377.8005453218421570',
#    'priceUsd': '0.2015983674484020',
#    'changePercent24Hr': '-5.5139189026989607',
#    'vwap24Hr': '0.2103232677643815',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'injective-protocol',
#    'rank': '36',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1845298369.2611700576418634',
#    'volumeUsd24Hr': '40237353.9752849758116716',
#    'priceUsd': '25.2761366747527860',
#    'changePercent24Hr': '-1.9456314915922030',
#    'vwap24Hr': '26.0803351737993150',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'lido-dao',
#    'rank': '37',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '892898392.8808856000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1682976481.7820568577534463',
#    'volumeUsd24Hr': '7492318.3173279213281270',
#    'priceUsd': '1.8848465796338030',
#    'changePercent24Hr': '-0.5619028234506108',
#    'vwap24Hr': '1.9638515915236359',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'cosmos',
#    'rank': '38',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1572168897.7256379453485682',
#    'volumeUsd24Hr': '50147747.1874366251732598',
#    'priceUsd': '6.3278270974083282',
#    'changePercent24Hr': '-3.8896405682910063',
#    'vwap24Hr': '6.5023772840724149',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'thorchain',
#    'rank': '39',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '336861028.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1493455364.7767445603816296',
#    'volumeUsd24Hr': '82767978.1652517109810495',
#    'priceUsd': '4.4334465570079082',
#    'changePercent24Hr': '5.3148092492365524',
#    'vwap24Hr': '4.4199086668268666',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'theta',
#    'rank': '40',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '1459862001.2222110000000000',
#    'volumeUsd24Hr': '10314357.2417794025926987',
#    'priceUsd': '1.4598620012222110',
#    'changePercent24Hr': '-4.2846652723963348',
#    'vwap24Hr': '1.5073274495202873',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'aave',
#    'rank': '41',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14875384.9283356700000000',
#    'maxSupply': None,
#    'marketCapUsd': '1434200126.4129652338014267',
#    'volumeUsd24Hr': '35136399.3207782682208951',
#    'priceUsd': '96.4143202560762560',
#    'changePercent24Hr': '-2.1748359023328685',
#    'vwap24Hr': '98.7409196124602207',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'fantom',
#    'rank': '42',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1346281009.4254061307512095',
#    'volumeUsd24Hr': '47929628.1147002983321887',
#    'priceUsd': '0.4801912832462509',
#    'changePercent24Hr': '-7.2296784856194117',
#    'vwap24Hr': '0.5072916595213466',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'algorand',
#    'rank': '43',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8229242570.8706370000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '1241755628.4603863645575625',
#    'volumeUsd24Hr': '24749494.3666485195993560',
#    'priceUsd': '0.1508954946662863',
#    'changePercent24Hr': '-5.0506957551081654',
#    'vwap24Hr': '0.1557415272090210',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'hedera-hashgraph',
#    'rank': '44',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '1073277637.3635835717496132',
#    'volumeUsd24Hr': '13893438.8713938296545835',
#    'priceUsd': '0.0723586119354719',
#    'changePercent24Hr': '-5.6899011044624586',
#    'vwap24Hr': '0.0752652456686496',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'kucoin-token',
#    'rank': '45',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '95540492.2885607500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '929831084.5145699283352415',
#    'volumeUsd24Hr': '812762.0681729381472835',
#    'priceUsd': '9.7323246117070764',
#    'changePercent24Hr': '0.4923402036478924',
#    'vwap24Hr': '9.6825718025209290',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'flow',
#    'rank': '46',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1511780104.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '912196764.3139880148560912',
#    'volumeUsd24Hr': '12503051.4614600838155577',
#    'priceUsd': '0.6033924920035778',
#    'changePercent24Hr': '-2.9699094299147759',
#    'vwap24Hr': '0.6219463928284842',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'quant',
#    'rank': '47',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '903332330.8672489872065952',
#    'volumeUsd24Hr': '3757909.7124370373421699',
#    'priceUsd': '74.8241476678487504',
#    'changePercent24Hr': '-4.8967781765442978',
#    'vwap24Hr': '76.9714457965574658',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'elrond-egld',
#    'rank': '48',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '899759393.0831852022242061',
#    'volumeUsd24Hr': '17424555.8206981050053696',
#    'priceUsd': '37.2038781447428370',
#    'changePercent24Hr': '0.9771151456368475',
#    'vwap24Hr': '37.5602090368157437',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'axie-infinity',
#    'rank': '49',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '147958602.9542522400000000',
#    'maxSupply': None,
#    'marketCapUsd': '899045548.1125185926716393',
#    'volumeUsd24Hr': '17494493.0773339329651649',
#    'priceUsd': '6.0763316911724096',
#    'changePercent24Hr': '-1.0688269134646464',
#    'vwap24Hr': '6.2088103567164298',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'eos',
#    'rank': '50',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1502498727.9200000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '882608351.0950509307506269',
#    'volumeUsd24Hr': '40458573.8372362964878223',
#    'priceUsd': '0.5874270205319236',
#    'changePercent24Hr': '-4.1664571210323397',
#    'vwap24Hr': '0.6065728968729835',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'bitcoin-sv',
#    'rank': '51',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19730446.8750000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '874421842.0005437126532891',
#    'volumeUsd24Hr': '1698436.1818020356331748',
#    'priceUsd': '44.3184002643398675',
#    'changePercent24Hr': '-2.6171357138864650',
#    'vwap24Hr': '45.3831952847590513',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'gala',
#    'rank': '52',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '32898390206.4702900000000000',
#    'maxSupply': None,
#    'marketCapUsd': '825772315.9793624888269194',
#    'volumeUsd24Hr': '41105097.5938101109077701',
#    'priceUsd': '0.0251006906659206',
#    'changePercent24Hr': '-2.1057771186767501',
#    'vwap24Hr': '0.0279278041670868',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'akash-network',
#    'rank': '53',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '244766655.1642960000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '825698996.2666323477999671',
#    'volumeUsd24Hr': '4595882.6452224217105131',
#    'priceUsd': '3.3734129173452736',
#    'changePercent24Hr': '-7.2861923656093579',
#    'vwap24Hr': '3.5021610728983830',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'neo',
#    'rank': '54',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '800071236.3902199051722403',
#    'volumeUsd24Hr': '11985839.7142630804302759',
#    'priceUsd': '11.3422809117749613',
#    'changePercent24Hr': '-3.8197210554183546',
#    'vwap24Hr': '11.7478785308551809',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'tezos',
#    'rank': '55',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '989915856.0503760000000000',
#    'maxSupply': None,
#    'marketCapUsd': '783126579.8939116965252155',
#    'volumeUsd24Hr': '23522982.6559331901130698',
#    'priceUsd': '0.7911041884089783',
#    'changePercent24Hr': '-3.9968931541434480',
#    'vwap24Hr': '0.8131712858655465',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'the-sandbox',
#    'rank': '56',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2281231926.2233224000000000',
#    'maxSupply': None,
#    'marketCapUsd': '733839326.7848097627560679',
#    'volumeUsd24Hr': '14992330.6012272681095142',
#    'priceUsd': '0.3216855411977827',
#    'changePercent24Hr': '-5.1493384068780914',
#    'vwap24Hr': '0.3386735340845479',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'gatetoken',
#    'rank': '57',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '93236970.8431050300000000',
#    'maxSupply': None,
#    'marketCapUsd': '712397549.4611971503934164',
#    'volumeUsd24Hr': '1347078.0152322562547388',
#    'priceUsd': '7.6407195881555142',
#    'changePercent24Hr': '-0.9588992653188472',
#    'vwap24Hr': '7.7000694219143753',
#    'explorer': None},
#   {'id': 'conflux-network',
#    'rank': '58',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '4234905414.2900000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '711654352.5162910186309945',
#    'volumeUsd24Hr': '11706488.6436198037637167',
#    'priceUsd': '0.1680449225890451',
#    'changePercent24Hr': '-2.8243470102283352',
#    'vwap24Hr': '0.1741493861915288',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'pendle',
#    'rank': '59',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '156126569.8174244200000000',
#    'maxSupply': None,
#    'marketCapUsd': '708460931.0572725126211851',
#    'volumeUsd24Hr': '2023429.0733137216489112',
#    'priceUsd': '4.5377345565572345',
#    'changePercent24Hr': '-0.8947528908275128',
#    'vwap24Hr': '4.6326910121994722',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'nexo',
#    'rank': '60',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '695752723.2127081763705501',
#    'volumeUsd24Hr': '856013.2745667457306516',
#    'priceUsd': '1.2424155527609591',
#    'changePercent24Hr': '-1.9090642193813519',
#    'vwap24Hr': '1.2648521212687718',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'ecash',
#    'rank': '61',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19730801548091.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '693011025.1996319039414246',
#    'volumeUsd24Hr': '4454086.7587423577364732',
#    'priceUsd': '0.0000351233082706',
#    'changePercent24Hr': '-4.4515576603623289',
#    'vwap24Hr': '0.0000362112530093',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'helium',
#    'rank': '62',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': None,
#    'marketCapUsd': '684244666.5851553100416978',
#    'volumeUsd24Hr': '2687998.0969389775072900',
#    'priceUsd': '4.2532574196925673',
#    'changePercent24Hr': '1.0093650189718644',
#    'vwap24Hr': '4.2640973954743081',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'gnosis-gno',
#    'rank': '63',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '661911412.8314026655993844',
#    'volumeUsd24Hr': '801946.0727164764993090',
#    'priceUsd': '255.6049119904025913',
#    'changePercent24Hr': '-3.0235497899063601',
#    'vwap24Hr': '259.0439418143426337',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'decentraland',
#    'rank': '64',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '643737052.9222782272591050',
#    'volumeUsd24Hr': '20275862.7053903222959867',
#    'priceUsd': '0.3373318407447292',
#    'changePercent24Hr': '-6.9786795585125537',
#    'vwap24Hr': '0.3578742617719382',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'mantra-dao',
#    'rank': '65',
#    'symbol': 'OM',
#    'name': 'MANTRA DAO',
#    'supply': '500205033.1781248500000000',
#    'maxSupply': '888888888.0000000000000000',
#    'marketCapUsd': '637213852.1624192967488006',
#    'volumeUsd24Hr': '13522397.0023033940883816',
#    'priceUsd': '1.2739053186126280',
#    'changePercent24Hr': '0.4215683963640995',
#    'vwap24Hr': '1.2904390918343888',
#    'explorer': 'https://etherscan.io/token/0x3593d125a4f7849a1b059e64f4517a86dd60c95d'},
#   {'id': 'chiliz',
#    'rank': '66',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8919064798.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '618967592.8601626638596230',
#    'volumeUsd24Hr': '16919675.7717614587429049',
#    'priceUsd': '0.0693982616875885',
#    'changePercent24Hr': '-5.3720202875040463',
#    'vwap24Hr': '0.0725190497389662',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'mina',
#    'rank': '67',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1133536314.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '601767228.1494057341707466',
#    'volumeUsd24Hr': '6769363.0989296071044530',
#    'priceUsd': '0.5308760030633205',
#    'changePercent24Hr': '-5.7334628171957747',
#    'vwap24Hr': '0.5535346665567443',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'oasis-network',
#    'rank': '68',
#    'symbol': 'ROSE',
#    'name': 'Oasis',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '594846829.9965164284638360',
#    'volumeUsd24Hr': '7170356.9509760148416731',
#    'priceUsd': '0.0886032592027110',
#    'changePercent24Hr': '-3.3616103964309695',
#    'vwap24Hr': '0.0911871110378929',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'dexe',
#    'rank': '69',
#    'symbol': 'DEXE',
#    'name': 'DeXe',
#    'supply': '57103225.3406123900000000',
#    'maxSupply': '98942301.0000000000000000',
#    'marketCapUsd': '579858070.9921622028099710',
#    'volumeUsd24Hr': '525543.0939944526647261',
#    'priceUsd': '10.1545590031630191',
#    'changePercent24Hr': '-2.5874700977882110',
#    'vwap24Hr': '10.4825013313542913',
#    'explorer': 'https://etherscan.io/token/0xde4EE8057785A7e8e800Db58F9784845A5C2Cbd6'},
#   {'id': 'klaytn',
#    'rank': '70',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3704366690.8359630000000000',
#    'maxSupply': None,
#    'marketCapUsd': '573757127.8445624779738216',
#    'volumeUsd24Hr': '3034865.4395065386359148',
#    'priceUsd': '0.1548866987882031',
#    'changePercent24Hr': '-2.4391514427437145',
#    'vwap24Hr': '0.1570575377445119',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'iota',
#    'rank': '71',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3344331631.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '564567168.5317688784031583',
#    'volumeUsd24Hr': '4403858.0700449130096191',
#    'priceUsd': '0.1688131533662993',
#    'changePercent24Hr': '-2.4939227668975543',
#    'vwap24Hr': '0.1731026311577724',
#    'explorer': 'https://thetangle.org/'},
#   {'id': 'livepeer',
#    'rank': '72',
#    'symbol': 'LPT',
#    'name': 'Livepeer',
#    'supply': '33381215.3213726500000000',
#    'maxSupply': None,
#    'marketCapUsd': '531594743.0288953436347015',
#    'volumeUsd24Hr': '17397915.4912245449417942',
#    'priceUsd': '15.9249667188880509',
#    'changePercent24Hr': '-3.7877374438033517',
#    'vwap24Hr': '16.5802024948561955',
#    'explorer': 'https://explorer.livepeer.org/'},
#   {'id': '1inch',
#    'rank': '73',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1254333269.3605090000000000',
#    'maxSupply': None,
#    'marketCapUsd': '512375757.5668384182548880',
#    'volumeUsd24Hr': '8873879.9554363198548054',
#    'priceUsd': '0.4084845471953882',
#    'changePercent24Hr': '-5.5637669288512003',
#    'vwap24Hr': '0.4252442459608083',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'aioz-network',
#    'rank': '74',
#    'symbol': 'AIOZ',
#    'name': 'AIOZ Network',
#    'supply': '1108291539.7874827000000000',
#    'maxSupply': None,
#    'marketCapUsd': '512233881.8865559601623772',
#    'volumeUsd24Hr': '2127595.0228302143097072',
#    'priceUsd': '0.4621833366920566',
#    'changePercent24Hr': '-4.6273049761670451',
#    'vwap24Hr': '0.4763781663935646',
#    'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18'},
#   {'id': 'nervos-network',
#    'rank': '75',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '44577090765.7921140000000000',
#    'maxSupply': None,
#    'marketCapUsd': '509128320.9739007238391024',
#    'volumeUsd24Hr': '10128026.7281298104023549',
#    'priceUsd': '0.0114212998701252',
#    'changePercent24Hr': '-4.8240350010697823',
#    'vwap24Hr': '0.0119716498596606',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'zcash',
#    'rank': '76',
#    'symbol': 'ZEC',
#    'name': 'Zcash',
#    'supply': '16328268.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '504792184.6238162835441094',
#    'volumeUsd24Hr': '68395700.5001872220854490',
#    'priceUsd': '30.9152300438352525',
#    'changePercent24Hr': '-0.9487367929078496',
#    'vwap24Hr': '31.3447835145944704',
#    'explorer': 'https://explorer.zcha.in/'},
#   {'id': 'raydium',
#    'rank': '77',
#    'symbol': 'RAY',
#    'name': 'Raydium',
#    'supply': '263558659.9365040000000000',
#    'maxSupply': None,
#    'marketCapUsd': '504221865.5152088423255432',
#    'volumeUsd24Hr': '4337683.2230830958306209',
#    'priceUsd': '1.9131295690935935',
#    'changePercent24Hr': '-2.0752387731892322',
#    'vwap24Hr': '1.9407997056744942',
#    'explorer': 'https://explorer.solana.com/address/4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R'},
#   {'id': 'wemix',
#    'rank': '78',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '408026695.3205573600000000',
#    'maxSupply': '590000000.0000000000000000',
#    'marketCapUsd': '499813305.9479659802626653',
#    'volumeUsd24Hr': '1717639.9337843441523693',
#    'priceUsd': '1.2249524643364289',
#    'changePercent24Hr': '-1.2492554255946833',
#    'vwap24Hr': '1.2291688069407723',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'trueusd',
#    'rank': '79',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '495201532.6100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '495142859.8667442890039413',
#    'volumeUsd24Hr': '10189094.2476027132739597',
#    'priceUsd': '0.9998815174441273',
#    'changePercent24Hr': '0.0612128605730239',
#    'vwap24Hr': '0.9990015808779371',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'nxm',
#    'rank': '80',
#    'symbol': 'NXM',
#    'name': 'NXM',
#    'supply': '6594067.8412913900000000',
#    'maxSupply': None,
#    'marketCapUsd': '481056250.3754906852090246',
#    'volumeUsd24Hr': '269659.6008292344230853',
#    'priceUsd': '72.9528815829228811',
#    'changePercent24Hr': '-2.7584251711482896',
#    'vwap24Hr': '73.8216457640155593',
#    'explorer': 'https://etherscan.io/token/0xd7c49cee7e9188cca6ad8ff264c1da2e69d4cf3b'},
#   {'id': 'theta-fuel',
#    'rank': '81',
#    'symbol': 'TFUEL',
#    'name': 'Theta Fuel',
#    'supply': '6617824668.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '462102915.2251571185361508',
#    'volumeUsd24Hr': '1035159.0291394019669334',
#    'priceUsd': '0.0698270108997631',
#    'changePercent24Hr': '-2.5293967542862229',
#    'vwap24Hr': '0.0715891707013872',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'ftx-token',
#    'rank': '82',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': None,
#    'marketCapUsd': '461897516.5535396711754641',
#    'volumeUsd24Hr': '12419340.9326306580629423',
#    'priceUsd': '1.4043915862483322',
#    'changePercent24Hr': '-7.0257922904397551',
#    'vwap24Hr': '1.4756274415046454',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'pancakeswap',
#    'rank': '83',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '229075242.7843212500000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '450000670.8266151303518864',
#    'volumeUsd24Hr': '6040337.1142928237894623',
#    'priceUsd': '1.9644229789174530',
#    'changePercent24Hr': '-3.2802956416114118',
#    'vwap24Hr': '1.9951769863886074',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'kava',
#    'rank': '84',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082855129.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '447517520.6462022276417611',
#    'volumeUsd24Hr': '3911637.2108228562043720',
#    'priceUsd': '0.4132755238085059',
#    'changePercent24Hr': '-2.7251613640045276',
#    'vwap24Hr': '0.4197593505688749',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'synthetix-network-token',
#    'rank': '85',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '446960783.5924782465968639',
#    'volumeUsd24Hr': '12864106.9602026440597397',
#    'priceUsd': '1.9124038613675143',
#    'changePercent24Hr': '-1.7381436418775014',
#    'vwap24Hr': '1.9650148514899638',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'bitcoin-gold',
#    'rank': '86',
#    'symbol': 'BTG',
#    'name': 'Bitcoin Gold',
#    'supply': '17513923.5890000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '446255481.7790801301398207',
#    'volumeUsd24Hr': '109003.8203230244885555',
#    'priceUsd': '25.4800404667381657',
#    'changePercent24Hr': '-3.5513843727607449',
#    'vwap24Hr': '25.4262905548918584',
#    'explorer': 'https://explorer.bitcoingold.org/insight/'},
#   {'id': 'iotex',
#    'rank': '87',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378929.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '438253684.9474742792952008',
#    'volumeUsd24Hr': '9338738.2143649843928832',
#    'priceUsd': '0.0464183980161352',
#    'changePercent24Hr': '-2.8608442750436189',
#    'vwap24Hr': '0.0478792477182790',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'compound',
#    'rank': '88',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8359763.6429862100000000',
#    'maxSupply': None,
#    'marketCapUsd': '426043113.5384221183941039',
#    'volumeUsd24Hr': '10198380.6438879346706561',
#    'priceUsd': '50.9635357808075897',
#    'changePercent24Hr': '-1.0975548306318126',
#    'vwap24Hr': '51.7325657979983191',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'trust-wallet-token',
#    'rank': '89',
#    'symbol': 'TWT',
#    'name': 'Trust Wallet Token',
#    'supply': '416649900.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '424873016.4061121468132700',
#    'volumeUsd24Hr': '1519680.3171367889045107',
#    'priceUsd': '1.0197362735623173',
#    'changePercent24Hr': '-5.2860570297628997',
#    'vwap24Hr': '1.0554810553826806',
#    'explorer': 'https://explorer.binance.org/asset/TWT-8C2'},
#   {'id': 'fei-protocol',
#    'rank': '90',
#    'symbol': 'FEI',
#    'name': 'Fei Protocol',
#    'supply': '424996177.7889055600000000',
#    'maxSupply': None,
#    'marketCapUsd': '407622735.3520295264943863',
#    'volumeUsd24Hr': '198759.0620905293523797',
#    'priceUsd': '0.9591209442699850',
#    'changePercent24Hr': '-0.0852942119665747',
#    'vwap24Hr': '0.9593198366055266',
#    'explorer': 'https://etherscan.io/token/0x956F47F50A910163D8BF957Cf5846D573E7f87CA'},
#   {'id': 'xinfin-network',
#    'rank': '91',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '396137287.1271795914508196',
#    'volumeUsd24Hr': '1003230.8056847895200122',
#    'priceUsd': '0.0322238533172113',
#    'changePercent24Hr': '2.3309825373850454',
#    'vwap24Hr': '0.0325026255674383',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'wootrade',
#    'rank': '92',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1914389675.5056205000000000',
#    'maxSupply': None,
#    'marketCapUsd': '381477498.2311053125980737',
#    'volumeUsd24Hr': '11514702.0796175896721349',
#    'priceUsd': '0.1992684682288370',
#    'changePercent24Hr': '-3.7686894665766431',
#    'vwap24Hr': '0.2066163723070555',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'aragon',
#    'rank': '93',
#    'symbol': 'ANT',
#    'name': 'Aragon',
#    'supply': '43191429.8753035100000000',
#    'maxSupply': None,
#    'marketCapUsd': '369169825.7259914090253709',
#    'volumeUsd24Hr': '1629162.9274608437552836',
#    'priceUsd': '8.5472934513121909',
#    'changePercent24Hr': '-1.3916623570843958',
#    'vwap24Hr': '8.6471799431876554',
#    'explorer': 'https://etherscan.io/token/Aragon'},
#   {'id': 'kusama',
#    'rank': '94',
#    'symbol': 'KSM',
#    'name': 'Kusama',
#    'supply': '15221458.5319204700000000',
#    'maxSupply': None,
#    'marketCapUsd': '338138982.3969956107108606',
#    'volumeUsd24Hr': '6769761.7532195331279032',
#    'priceUsd': '22.2146242876721940',
#    'changePercent24Hr': '-2.7318929208993022',
#    'vwap24Hr': '22.8095219743325478',
#    'explorer': 'https://kusama.subscan.io/'},
#   {'id': 'golem-network-tokens',
#    'rank': '95',
#    'symbol': 'GLM',
#    'name': 'Golem',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '334204463.5441151000000000',
#    'volumeUsd24Hr': '637639.0574795663379828',
#    'priceUsd': '0.3342044635441151',
#    'changePercent24Hr': '-4.8468087591931937',
#    'vwap24Hr': '0.3461932255318994',
#    'explorer': 'https://etherscan.io/token/Golem'},
#   {'id': 'curve-dao-token',
#    'rank': '96',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1187812180.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '325687084.9985994958166660',
#    'volumeUsd24Hr': '9161253.9138508174539932',
#    'priceUsd': '0.2741907268526237',
#    'changePercent24Hr': '-4.7809940008083855',
#    'vwap24Hr': '0.2858240822268014',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'dash',
#    'rank': '97',
#    'symbol': 'DASH',
#    'name': 'Dash',
#    'supply': '11881381.6146700800000000',
#    'maxSupply': '18900000.0000000000000000',
#    'marketCapUsd': '323953252.9716494351314238',
#    'volumeUsd24Hr': '22547928.3090183524543170',
#    'priceUsd': '27.2656214132252589',
#    'changePercent24Hr': '-3.4470394133430979',
#    'vwap24Hr': '27.7544501528438700',
#    'explorer': 'https://explorer.dash.org'},
#   {'id': 'zilliqa',
#    'rank': '98',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '18704789775.0079500000000000',
#    'maxSupply': None,
#    'marketCapUsd': '319724997.1015218531093203',
#    'volumeUsd24Hr': '4329704.0933730665081602',
#    'priceUsd': '0.0170932152110427',
#    'changePercent24Hr': '-3.5809348260809717',
#    'vwap24Hr': '0.0175229165187806',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'illuvium',
#    'rank': '99',
#    'symbol': 'ILV',
#    'name': 'Illuvium',
#    'supply': '4476346.2731870700000000',
#    'maxSupply': None,
#    'marketCapUsd': '315548705.7108613173808574',
#    'volumeUsd24Hr': '5107895.3473304247140298',
#    'priceUsd': '70.4924700756442778',
#    'changePercent24Hr': '4.1775049852165278',
#    'vwap24Hr': '70.9626426513007229',
#    'explorer': 'https://etherscan.io/token/0x767fe9edc9e0df98e07454847909b5e959d7ca0e'},
#   {'id': 'enjin-coin',
#    'rank': '100',
#    'symbol': 'ENJ',
#    'name': 'Enjin Coin',
#    'supply': '1652989103.4489512000000000',
#    'maxSupply': None,
#    'marketCapUsd': '313584165.9999876636883600',
#    'volumeUsd24Hr': '3540926.8132852899956812',
#    'priceUsd': '0.1897073400820951',
#    'changePercent24Hr': '-3.9851110171879723',
#    'vwap24Hr': '0.1983800068612956',
#    'explorer': 'https://etherscan.io/token/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'}],
#  'timestamp': 1721318590754}

# %%
### Transformation (Restructuring and data cleaning)

# %%
df=pd.json_normalize(responsedata,"data")
df.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19727337.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120222728.1783115700000000
# 2        tether    3   USDT    Tether  113632416636.0384400000000000
# 3  binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4        solana    5    SOL    Solana     464274532.9981066000000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1254232347778.7421082733328108
# 1                        None   407678008060.3933285585608744
# 2                        None   113697208007.8713115451836848
# 3  166801148.0000000000000000    94290334283.1678562086414060
# 4                        None    72629019120.8561741118872127
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0  10442635998.9666159828229595  63578.3911319983081484  -1.8876116270482910
# 1   6614263909.0353558051394749   3391.0227644787326363  -1.4196188848735361
# 2  15989657217.2242741569992479      1.0005701838766696  -0.0149997044124572
# 3    201077694.5008487198199126    565.2858833032003845  -1.2803023727671828
# 4    748573293.4670278843723863    156.4355008917802715  -1.0648013943480714
#
#                  vwap24Hr                                           explorer
# 0  64513.8858409383567868                           https://blockchain.info/
# 1   3426.5667113271284740                              https://etherscan.io/
# 2      1.0004569030754881             https://www.omniexplorer.info/asset/31
# 3    572.0088495368418330  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4    158.1740592196204314                       https://explorer.solana.com/

# %%
df.info() #full description of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    object
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    object
#  5   maxSupply          36 non-null     object
#  6   marketCapUsd       100 non-null    object
#  7   volumeUsd24Hr      100 non-null    object
#  8   priceUsd           100 non-null    object
#  9   changePercent24Hr  100 non-null    object
#  10  vwap24Hr           100 non-null    object
#  11  explorer           99 non-null     object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %%
#### Step 3: Converting Categorical Data to Numerical Data
def convert_columns_to_datatypes(data,column_datatypes):
    for column, datatype in column_datatypes.items():
        if column in data.columns:
            data[column]=data[column].astype(datatype)
    return data

# %%
column_datatypes={
    'rank':int,
    'supply':float,
    'maxSupply':float,
'marketCapUsd':float,
'volumeUsd24Hr':float,
'priceUsd' :float,
'changePercent24Hr':float,
'vwap24Hr':float
}

df=convert_columns_to_datatypes(df,column_datatypes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int32
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          36 non-null     float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           100 non-null    float64
#  11  explorer           99 non-null     object
# dtypes: float64(7), int32(1), object(4)
# memory usage: 9.1+ KB

# %%
#### Step 4: Dealing with missing values
df['maxSupply']=df['maxSupply'].fillna(0)
df['explorer']=df['explorer'].fillna('not available')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int32
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          100 non-null    float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           100 non-null    float64
#  11  explorer           100 non-null    object
# dtypes: float64(7), int32(1), object(4)
# memory usage: 9.1+ KB

# %%
#### Step 5: Round number to 2 decimal

# %%
def round_to_two_decimal_places(number):
    return round(number, 2)

# %%
selected_columns=["supply","maxSupply","marketCapUsd","priceUsd","changePercent24Hr","vwap24Hr"]
df[selected_columns]=df[selected_columns].map(round_to_two_decimal_places)
df.head()
# Out:
#              id  rank symbol      name        supply    maxSupply  \
# 0       bitcoin     1    BTC   Bitcoin  1.972734e+07   21000000.0
# 1      ethereum     2    ETH  Ethereum  1.202227e+08          0.0
# 2        tether     3   USDT    Tether  1.136324e+11          0.0
# 3  binance-coin     4    BNB       BNB  1.668011e+08  166801148.0
# 4        solana     5    SOL    Solana  4.642745e+08          0.0
#
#    marketCapUsd  volumeUsd24Hr  priceUsd  changePercent24Hr  vwap24Hr  \
# 0  1.254232e+12   1.044264e+10  63578.39              -1.89  64513.89
# 1  4.076780e+11   6.614264e+09   3391.02              -1.42   3426.57
# 2  1.136972e+11   1.598966e+10      1.00              -0.01      1.00
# 3  9.429033e+10   2.010777e+08    565.29              -1.28    572.01
# 4  7.262902e+10   7.485733e+08    156.44              -1.06    158.17
#
#                                             explorer
# 0                           https://blockchain.info/
# 1                              https://etherscan.io/
# 2             https://www.omniexplorer.info/asset/31
# 3  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4                       https://explorer.solana.com/

# %%
# selected_columns=["supply","maxSupply","marketCapUsd","priceUsd","changePercent24Hr","vwap24Hr"]
# df[selected_columns]=df[selected_columns].applymap(round_to_two_decimal_places)
# df.head()

# %%
#Load the data into a PostgreSQL database

# %%
 #Database Credentials
db_username = 'postgres'
db_password = 'Eai@810675'  
db_host = 'localhost'
db_port = 5432
db_name = 'crypto_data'

# %%
# Forming the connection string
conn_str = f"dbname='{db_name}' user='{db_username}' host='{db_host}' port='{db_port}' password='{db_password}'"

# Attempting to connect
try:
    conn = psycopg2.connect(conn_str)
    # If connection is successful, you can proceed with your operations here
    print("Connected to the database successfully")
except psycopg2.OperationalError as e:
    print(f"An error occurred: {e}")
# Out:
# Connected to the database successfully

# %%
# pip install psycopg2

# %%
import psycopg2 #for connecting to PostgreSQL databases and executing queries
from sqlalchemy import create_engine #To efficiency manage and reuse database connections

# %%
from sqlalchemy.engine.url import URL

# Your database credentials
db_credentials = {
    "drivername": "postgresql",
    "username": db_username,
    "password": db_password,
    "host": db_host,
    "port": db_port,
    "database": db_name
}

# Create the engine using the URL object
engine = create_engine(URL.create(**db_credentials))

# Test the connection
try:
    conn = engine.connect()
    print("Connected to the database successfully")
    conn.close()
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Connected to the database successfully

# %%
#Establish a connection with sqlalchemy engine
# engine=create_engine(f'postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# %%
#create a table
table_name='crypto_data'

#load the data into the table
df.to_sql(table_name,engine, if_exists='replace',index=False)

#Close the engine connection
engine.dispose()
